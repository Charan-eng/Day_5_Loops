# %%
n=6
for i in range(1,n+1):
  if i==1:
    print((n-i)*" " +"*")
  else:
    print((n-i)*" "+"*"+" "*(2*i-3)+"*")
for i in range(n-1,0,-1):
  if i==1:
    print((n-i)*" " +"*")
  else:
    print((n-i)*" "+"*"+" "*(2*i-3)+"*")
# Out:
#      *
#     * *
#    *   *
#   *     *
#  *       *
# *         *
#  *       *
#   *     *
#    *   *
#     * *
#      *

# %%
for i in range(0,7)         :
  for j in range(i+1):
    print("*",end=" ")
  print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * * * *
# * * * * * * *

# %% [markdown]
# While loop()

# %%
i=1
n=int(input("enter the number:"))
while i<11:
  print(f"{n}*{i}={n*i}")
  i+=1
# Out:
# enter the number:5
# 5*1=5
# 5*2=10
# 5*3=15
# 5*4=20
# 5*5=25
# 5*6=30
# 5*7=35
# 5*8=40
# 5*9=45
# 5*10=50

# %%
import random

num_to_guess = random.randint(1,100)
guess=0
while guess!=num_to_guess:
  guess=int(input("guess the number between 1 to 100:"))
  if guess < num_to_guess:
    print("too low! try again.")
  elif guess>num_to_guess:
    print("too high! try again.")
  else:
    print("congratulation! You guessed it right")
# Out:
# guess the number between 1 to 100:53
# too high! try again.
# guess the number between 1 to 100:23
# too low! try again.
# guess the number between 1 to 100:40
# too low! try again.
# guess the number between 1 to 100:45
# too high! try again.
# guess the number between 1 to 100:43
# too high! try again.
# guess the number between 1 to 100:41
# congratulation! You guessed it right

# %%
i=10
while i<=1:
  print("the numbers are",i)
i+=1

# %%
i=10
while i<=1:
  i=i+1
  if i==3:
    continue
    print(i)

# %%
i=1
while i<=10:
  i=i+1
  if  i==6:
      continue
      print(i)
